# %%
import numpy as np
import matplotlib.pyplot as mpl
from scipy.optimize import curve_fit

# %%
x = np.array([1,2,3])
year = np.array([2011,2012,2013])
revenue = np.array([156.8,161.7,177.2])

# %%
mpl.plot(x,y,)

# %%
def func_2(x,a,b,c):
    y = a*x**2+b*x+c
    return y

# %%
p_ini = np.array([1.,1.,1.])
best_param = curve_fit(func_2,x,revenue,p0=p_ini,maxfev=100000)

# %%
a_best,b_best,c_best = best_param[0]
mpl.plot(x,revenue,'o')
mpl.plot(x,func_2(x,a_best,b_best,c_best))
